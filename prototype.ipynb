# %%
import requests
from bs4 import BeautifulSoup
from deep_translator import GoogleTranslator
import typing
from pathlib import Path

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
import PyPDF2

# %%
text_de = 'das ist auf deutsch'
translated = GoogleTranslator(source='auto', target='en').translate(text_de)

# %%
translated
# Out:
# 'This is in german'

# %%
from nltk.tokenize import sent_tokenize, word_tokenize
import nltk
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('punkt')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to /Users/acm/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/acm/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/acm/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
from nltk.stem import PorterStemmer

# %%
from nltk.stem import SnowballStemmer

# %%
from nltk.stem import WordNetLemmatizer

# %%
from nltk import FreqDist

# %%
lemmatizer = WordNetLemmatizer()

# %%
lemmatizer.lemmatize('wolvessssssssssss')
# Out:
# 'wolf'

# %%
text= 'Some text here and there'

# %%
frequency_distribution = FreqDist(text)
frequency_distribution
# Out:
# FreqDist({'e': 6, ' ': 4, 't': 3, 'h': 2, 'r': 2, 'S': 1, 'o': 1, 'm': 1, 'x': 1, 'a': 1, ...})

# %%
frequency_distribution.most_common(20)
# Out:
# [('e', 6),
#  (' ', 4),
#  ('t', 3),
#  ('h', 2),
#  ('r', 2),
#  ('S', 1),
#  ('o', 1),
#  ('m', 1),
#  ('x', 1),
#  ('a', 1),
#  ('n', 1),
#  ('d', 1)]

# %%
meaningful_words = [
...     word for word in text8 if word.casefold() not in stop_words
... ]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 2
#       1 meaningful_words = [
# ----> 2     word for word in text8 if word.casefold() not in stop_words
#       3 ]
#
# NameError: name 'text8' is not defined

# %%
stemmer2 = SnowballStemmer('german')

# %%
text= 'So once was a boy he was such a coy you marvel and you gander youre a trash youre a toy'

# %%
text.concordance('you')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 text.concordance('you')
#
# AttributeError: 'str' object has no attribute 'concordance'

# %%
text.dispersion_plot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 text.dispersion_plot()
#
# AttributeError: 'str' object has no attribute 'dispersion_plot'

# %%
sentence = sent_tokenize(text)

# %%
words = word_tokenize(text)

# %%
words
# Out:
# ['Some', 'text', 'here', 'and', 'there']

# %%
stemmer = PorterStemmer()

# %%
stop_words_de = set(stopwords.words('german'))

# %%
stop_words_en = set(stopwords.words('english'))

# %%
filtered= [word for word in words if word.lower() not in stop_words_en]

# %%
filtered= [word for word in words if word.casefold() not in stop_words_en]

# %%
filtered
# Out:
# ['text']

# %%
URL = 'https://www.gefasoft.de/wp-content/uploads/2022/02/GE-0023_Sales_Factsheet_A4_GEFASOFT_Sapient_EN_220216.pdf'

# %%
page = requests.get(URL)

# %%
soup = BeautifulSoup(page.content, 'html.parser')
# Out:
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.

# %%
page.text
# Out:
# '%PDF-1.4\n%�쏢\n%%Invocation: path/gs -P- -dSAFER -dCompatibilityLevel=1.4 -q -P- -dNOPAUSE -dBATCH -sDEVICE=pdfwrite -sstdout=? -sOutputFile=? -P- -dSAFER -dCompatibilityLevel=1.4 -dAutoRotatePages=/None -dPDFSETTINGS=/ebook -dDetectDuplicateImages=true\n%%+ -dEmbedAllFonts=true -dSubsetFonts=true -dCompressFonts=true -dNOPAUSE -dQUIET -dBATCH -f ?\n5 0 obj\n<</Length 6 0 R/Filter /FlateDecode>>\nstream\nx��[[s\x1e��}�H�)5�V�\x05�Kޔ��z�v�\x16S�-g\x1f(����E\x16%{��~��\x060\x18���U[z�\x07\x0c\x06h���i`��b�v1�����=��$�x��.9Gs�n�6�����h���j��rwb��������\x12�1-�\'ɔ��\x06\x1d�h\x1c;L<���l��E̝���%z,��h_��\x12��l=!�c�\t3Xw4ej�t��x��Tc�\x01o�|��h�t\x0ce[��/Nb�ǐ�\x11Ŷ7�;ִ�\x1a�s�6��d�n��|L\x0e;�5C9�\t���N�T\\%A)Ӣ҄��y�w��#\'\x0c�����ޓ+�gs�ؽ��Nz�6�T\rD��\'ak���Gc̾��|t�\x1b\x1a��=/O���;�\'�!C�\x05K�-�\x1dj9fh�u���Gn�y�7�F\x0f�\'VȀ\u05cf5�\'{(����z��sO\t�\x85�L�a4�v�{\x13�{D1�\x18�6��?\x08=|j���[\x0f�2/\x05���\x1d~;�\x18��a3c�6�d]3\x17�\x1f�T=�Mf4�\x15�\x03>�ń�X-�\x05#��ѓ����eA5��`w�b1ȸ�S�?r~zD��
# ...

# %%
if 'Digital' in  page.text:
    print('yes')
else:
    print('No')
# Out:
# No

# %%
stuff = soup.find(id='divtext')

# %%
print(stuff.prettify())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 print(stuff.prettify())
#
# AttributeError: 'NoneType' object has no attribute 'prettify'

# %%
#Open Strings from Anforderung; split and treat to form tags

with open('strings.txt', 'r') as requirements:
    text = requirements.read()
    print(text)
    tags = text.split()
    print(tags)






legato_sapient = ['https://www.gefasoft.de/en/mes-system-legato-sapient/','https://www.gefasoft.de/wp-content/uploads/2021/12/factsheet-legato-sapient-en-211115.pdf']

url_keys = {
    'gefasoft':legato_sapient
}

print(url_keys)

URL= url_keys['gefasoft'][0]

page = requests.get(URL)

print(page.text)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[52], line 3
#       1 #Open Strings from Anforderung; split and treat to form tags
# ----> 3 with open('strings.txt', 'r') as requirements:
#       4     text = requirements.read()
#       5     print(text)
#
# File ~/Documents/dsfm-scraper/venv/lib/python3.11/site-packages/IPython/core/interactiveshell.py:284, in _modified_open(file, *args, **kwargs)
#     277 if file in {0, 1, 2}:
#     278     raise ValueError(
#     279         f"IPython won't let you open fd={file} by default "
#     280         "as it is likely to crash IPython. If you know what you are doing, "
#     281         "you can use builtins' open."
#     282     )
# --> 284 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'strings.txt'

# %%
with open('tags.txt', 'r') as tags:
    tag = tags.read()
    #tag = tag.split()
    print(tag)
# Out:
# Datenanbindung
# Systemanbindung		Die Ist- und Zielwerte von Kennzahlen sollen aus verschiedenen Systemen importiert werden können
# 	Office	Kennzahlen sollen aus Officeprogrammen importiert werden können.
# 	SAP	Kennzahlen sollen aus SAP importiert werden können.
# 	REST	Kennzahlen sollen aus REST-Schnittstellen importiert werden können.
# 	OPC UA	Kennzahlen sollen über OPC UA importiert werden können.
# 	SQL	Kennzahlen sollen über SQL-Queries importiert werden können.
# Dynamische Zielwerte		Auch der Zielwert von Kennzahlen soll aus Datenquellen gezogen werden können
# Kennzahlenvisualisierung
# Aggregation		Das System muss Werte aus verschiedenen Datenquellen berechnen können.
# 	Berechnete Kennzahlen	Kennzahlen aus mehreren Einzelwerten bestimmen (z.B. OEE)
# 	Aggregation in Hierarchie	Aggregation von Werten mehrerer Teams für höhere Ebenen durch Bildung von Summen, Durchschnitten oder Weitergabe des Maximums.
# ...

# %%
tag_comparison_keys = word_tokenize(tag)

# %%
tag_comparison_keys
# Out:
# ['Datenanbindung',
#  'Systemanbindung',
#  'Die',
#  'Ist-',
#  'und',
#  'Zielwerte',
#  'von',
#  'Kennzahlen',
#  'sollen',
#  'aus',
#  'verschiedenen',
#  'Systemen',
#  'importiert',
#  'werden',
#  'können',
#  'Office',
#  'Kennzahlen',
#  'sollen',
#  'aus',
#  'Officeprogrammen',
#  'importiert',
#  'werden',
#  'können',
#  '.',
#  'SAP',
#  'Kennzahlen',
#  'sollen',
#  'aus',
#  'SAP',
#  'importiert',
#  'werden',
#  'können',
#  '.',
#  'REST',
#  'Kennzahlen',
#  'sollen',
#  'aus',
#  'REST-Schnittstellen',
#  'importiert',
#  'werden',
#  'können',
#  '.',
#  'OPC',
#  'UA',
#  'Kennzahlen',
#  'sollen',
#  'über',
#  'OPC',
#  'UA',
#  'importiert',
#  'werden',
#  'können',
#  '.',
#  'SQL',
#  'Kennzahlen',
#  'sollen',
#  'über',
#  'SQL-Queries',
#  'importiert',
#  'werden',
#  'können',
#  '.',
#  'Dynamische',
#  'Zielwerte',
#  'Auch',
#  'der',
#  'Zielwert',
#  'von',
#  'Kennzahlen',
#  'soll',
#  'aus',
#  'Datenquellen',
#  'gezogen',
#  'werden',
# ...

# %%
filtered_keys_de = [tag for tag in tag_comparison_keys if tag.casefold() not in stop_words_de]

# %%
filtered_keys_de
# Out:
# ['Datenanbindung',
#  'Systemanbindung',
#  'Ist-',
#  'Zielwerte',
#  'Kennzahlen',
#  'sollen',
#  'verschiedenen',
#  'Systemen',
#  'importiert',
#  'Office',
#  'Kennzahlen',
#  'sollen',
#  'Officeprogrammen',
#  'importiert',
#  '.',
#  'SAP',
#  'Kennzahlen',
#  'sollen',
#  'SAP',
#  'importiert',
#  '.',
#  'REST',
#  'Kennzahlen',
#  'sollen',
#  'REST-Schnittstellen',
#  'importiert',
#  '.',
#  'OPC',
#  'UA',
#  'Kennzahlen',
#  'sollen',
#  'OPC',
#  'UA',
#  'importiert',
#  '.',
#  'SQL',
#  'Kennzahlen',
#  'sollen',
#  'SQL-Queries',
#  'importiert',
#  '.',
#  'Dynamische',
#  'Zielwerte',
#  'Zielwert',
#  'Kennzahlen',
#  'Datenquellen',
#  'gezogen',
#  'Kennzahlenvisualisierung',
#  'Aggregation',
#  'System',
#  'Werte',
#  'verschiedenen',
#  'Datenquellen',
#  'berechnen',
#  '.',
#  'Berechnete',
#  'Kennzahlen',
#  'Kennzahlen',
#  'mehreren',
#  'Einzelwerten',
#  'bestimmen',
#  '(',
#  'z.B',
#  '.',
#  'OEE',
#  ')',
#  'Aggregation',
# ...

# %%
lemmatized_filtered_de = [lemmatizer.lemmatize(filtered_key_de) for filtered_key_de in filtered_keys_de]

# %%
lemmatized_filtered_de
# Out:
# ['Datenanbindung',
#  'Systemanbindung',
#  'Ist-',
#  'Zielwerte',
#  'Kennzahlen',
#  'sollen',
#  'verschiedenen',
#  'Systemen',
#  'importiert',
#  'Office',
#  'Kennzahlen',
#  'sollen',
#  'Officeprogrammen',
#  'importiert',
#  '.',
#  'SAP',
#  'Kennzahlen',
#  'sollen',
#  'SAP',
#  'importiert',
#  '.',
#  'REST',
#  'Kennzahlen',
#  'sollen',
#  'REST-Schnittstellen',
#  'importiert',
#  '.',
#  'OPC',
#  'UA',
#  'Kennzahlen',
#  'sollen',
#  'OPC',
#  'UA',
#  'importiert',
#  '.',
#  'SQL',
#  'Kennzahlen',
#  'sollen',
#  'SQL-Queries',
#  'importiert',
#  '.',
#  'Dynamische',
#  'Zielwerte',
#  'Zielwert',
#  'Kennzahlen',
#  'Datenquellen',
#  'gezogen',
#  'Kennzahlenvisualisierung',
#  'Aggregation',
#  'System',
#  'Werte',
#  'verschiedenen',
#  'Datenquellen',
#  'berechnen',
#  '.',
#  'Berechnete',
#  'Kennzahlen',
#  'Kennzahlen',
#  'mehreren',
#  'Einzelwerten',
#  'bestimmen',
#  '(',
#  'z.B',
#  '.',
#  'OEE',
#  ')',
#  'Aggregation',
# ...

# %%
[lemmatized_filtered_de[i] == filtered_keys_de[i] for i in range(len(filtered_keys_de))]
# Out:
# [True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
# ...

# %%
max([len(i) for i in tag_comparison_keys])
# Out:
# 27

# %%
tag_comparison_keys_en = [ GoogleTranslator(source='auto', target='en').translate(tag_comparison_key) for tag_comparison_key in filtered_keys_de[:500]]

# %%
tag_comparison_keys_en
# Out:
# ['data connection',
#  'system connection',
#  'Is-',
#  'target values',
#  'metrics',
#  'should',
#  'different',
#  'Systems',
#  'imported',
#  'Office',
#  'metrics',
#  'should',
#  'Office programming',
#  'imported',
#  None,
#  'SAP',
#  'metrics',
#  'should',
#  'SAP',
#  'imported',
#  None,
#  'REST',
#  'metrics',
#  'should',
#  'REST interfaces',
#  'imported',
#  None,
#  'OPC',
#  'UA',
#  'metrics',
#  'should',
#  'OPC',
#  'UA',
#  'imported',
#  None,
#  'SQL',
#  'metrics',
#  'should',
#  'SQL-Queries',
#  'imported',
#  None,
#  'Dynamic',
#  'target values',
#  'target value',
#  'metrics',
#  'data sources',
#  'pulled',
#  'KPI visualization',
#  'Aggregation',
#  'System',
#  'Values',
#  'different',
#  'data sources',
#  'calculate',
#  None,
#  'calculated',
#  'metrics',
#  'metrics',
#  'several',
#  'individual values',
#  'determine',
#  None,
#  'z.B',
#  None,
#  'OEE',
#  None,
#  'Aggregation',
#  'hierarchy',
#  'Aggregation',
#  'values',
# ...

# %%
legato_sapient = ['https://www.gefasoft.de/en/mes-system-legato-sapient/','https://www.gefasoft.de/wp-content/uploads/2021/12/factsheet-legato-sapient-en-211115.pdf']

# %%
collection_website = {
    'gefasoft': legato_sapient
}

# %%
#For Dynamic Website
def scapre_dyn_url (url):
    options = Options()
    options.headless=True
    driver = webdriver.Chrome(options=options)
    driver.get(url)
    #extract data
    None
    driver.quit()

# %%
#For Static Website 
def scrape_stat_url(url):
    response = requests.get(url)
    if 'html' in url.lower():
        #Use BeautifulSoup to parse HTML 
        soup =BeautifulSoup(response.content, 'html.parser')
        #Extract data 
        None
    if 'pdf' in url.lower():
        #Save file locally
        with open('file.pdf','wb') as file:
            file.write(response.content)
        #Extract text from PDF
        with open('file.pdf', 'rb') as f:
            pdf_reader = PyPDF2.PdfReader(f)
            num_pages = len(pdf_reader.pages)
            text = ''
            for page_num in range(num_pages):
                page = pdf_reader.pages[page_num]
                text += page.extract_text()
            print(text)

        #Extract Data
        None
        return text

# %%
legato_sapient[0]
# Out:
# 'https://www.gefasoft.de/en/mes-system-legato-sapient/'

# %%
text = scrape_stat_url(URL)
# Out:
#   Reducing downtime through real-time detection
# of machine stoppages
#   Faster reaction & shorter solution time in
# maintenance management through automatic
# alerting in case of malfunctions
#   Targeted recall actions and fewer callbacks
# through tracking & tracing
#   Increased transparency and fast detection of
# deviations through automatic calculation of key
# performance indicators
#   Reduction of training and engineering efforts
# through intuitive drag-and-drop operation and easy
# report generation via the flexible dashboard
#   Avoidance of machine failures (crash) through
# condition-based maintenanceDIGITAL MANUFACTURING:
# TRANSPARENCY DOWN TO
# THE SMALLEST DETAILMES Software Legato Sapient
# In the age of digitalization, efficiency is not only a question of productivit y, but also it is the
# adequate handling of various forms of disruption. Transparent manuf acturing processes are
# ...

# %%
text
